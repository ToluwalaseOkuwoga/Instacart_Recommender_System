# %%
import numpy as np
import pandas as pd

# %%
# Loading the files
order_products_prior = pd.read_csv("order_products__prior.csv")
orders = pd.read_csv("orders.csv")
products = pd.read_csv("products.csv")

# %%
order_products_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
orders_prior = orders[orders.eval_set=="prior"]
orders_prior.head(10)
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
# 5   3367565        1    prior             6          2                  7
# 6    550135        1    prior             7          1                  9
# 7   3108588        1    prior             8          1                 14
# 8   2295261        1    prior             9          1                 16
# 9   2550362        1    prior            10          4                  8
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# ...

# %%
orders_prior = orders_prior.iloc[:, 0:4]
orders_prior.head()
# Out:
#    order_id  user_id eval_set  order_number
# 0   2539329        1    prior             1
# 1   2398795        1    prior             2
# 2    473747        1    prior             3
# 3   2254736        1    prior             4
# 4    431534        1    prior             5

# %%
product = products.iloc[:, 0:2]
product.head()
# Out:
#    product_id                                       product_name
# 0           1                         Chocolate Sandwich Cookies
# 1           2                                   All-Seasons Salt
# 2           3               Robust Golden Unsweetened Oolong Tea
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           5                          Green Chile Anytime Sauce

# %%
order_product_prior = order_products_prior.iloc[:, :]
# order_product_prior.head()

# %%
orders_all = pd.merge(orders_prior, order_product_prior, how = 'left', on = 'order_id')
orders_all.head()
# Out:
#    order_id  user_id eval_set  order_number  product_id  add_to_cart_order  \
# 0   2539329        1    prior             1         196                  1
# 1   2539329        1    prior             1       14084                  2
# 2   2539329        1    prior             1       12427                  3
# 3   2539329        1    prior             1       26088                  4
# 4   2539329        1    prior             1       26405                  5
#
#    reordered
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
orders_all_product = pd.merge(orders_all, product, how = 'left', on = 'product_id')
orders_all_product.head()
# Out:
#    order_id  user_id eval_set  order_number  product_id  add_to_cart_order  \
# 0   2539329        1    prior             1         196                  1
# 1   2539329        1    prior             1       14084                  2
# 2   2539329        1    prior             1       12427                  3
# 3   2539329        1    prior             1       26088                  4
# 4   2539329        1    prior             1       26405                  5
#
#    reordered                             product_name
# 0          0                                     Soda
# 1          0  Organic Unsweetened Vanilla Almond Milk
# 2          0                      Original Beef Jerky
# 3          0               Aged White Cheddar Popcorn
# 4          0         XL Pick-A-Size Paper Towel Rolls

# %%
#orders_all_product['order_id'].count()

# %%
#orders_all_2 = orders_all_product.iloc[:1000000, :]

# %%
# grouped = orders_all_2.groupby(['user_id', 'product_name']).agg({'reordered': ['count', 'mean']})
# grouped.columns = ['reordered_count', 'reordered_mean']
# grouped = grouped.reset_index()
# grouped.head()

# %%
# ratings = pd.DataFrame(orders_all_2.groupby(['product_name'])['reordered'].count().sort_values(ascending = False))
# ratings = ratings.rename(columns={'reordered':'reordered_count'})
# ratings

# %%
grouped2 = pd.DataFrame(orders_all_product.groupby(['user_id', 'product_name'])['reordered'].count())
grouped2 = grouped2.reset_index()
grouped2.head()
#grouped2.to_csv('grouped_table')
# Out:
#    user_id                product_name  reordered
# 0        1    0% Greek Strained Yogurt          1
# 1        1  Aged White Cheddar Popcorn          2
# 2        1      Bag of Organic Bananas          2
# 3        1              Bartlett Pears          1
# 4        1       Cinnamon Toast Crunch          3

# %%
grouped2 = grouped2[grouped2['reordered'] >= 5]
grouped2.head()
# Out:
#     user_id                              product_name  reordered
# 10        1                     Organic String Cheese          8
# 13        1                       Original Beef Jerky         10
# 14        1                                Pistachios          9
# 15        1                                      Soda         10
# 23        2  Baked Organic Sea Salt Crunchy Pea Snack          5

# %%
grouped2.to_csv('greater_than_5')

# %%
Banana_reordering = matrix['Banana']
Banana_reordering
# Out:
# user_id
# 1        NaN
# 2        7.0
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       1.0
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# 15       NaN
# 16       3.0
# 17       NaN
# 18       NaN
# 19       NaN
# 20       NaN
# 21       3.0
# 22       NaN
# 23       NaN
# 24       NaN
# 25       NaN
# 26       NaN
# 27       5.0
# 28       6.0
# 29       NaN
# 30       NaN
#         ...
# 6438     NaN
# 6439     2.0
# 6440     NaN
# 6441     4.0
# 6442     NaN
# 6443     NaN
# 6444     NaN
# 6445     NaN
# 6446     NaN
# 6447     NaN
# 6448    20.0
# 6449     NaN
# 6450     NaN
# 6451     NaN
# 6452    10.0
# 6453    19.0
# 6454     2.0
# 6455     NaN
# 6456     NaN
# 6457     NaN
# 6458     NaN
# 6459     NaN
# 6460     NaN
# 6461     NaN
# 6462     NaN
# 6463     NaN
# 6464     6.0
# 6465     1.0
# 6466     2.0
# 6467     NaN
# Name: Banana, Length: 6467, dtype: float64

# %%
similar_to_Banana = pd.DataFrame(matrix.corrwith(Banana_reordering),columns=["Correlation"]).sort_values('Correlation',ascending=False)
similar_to_Banana
# Out:
#                                                     Correlation
# product_name
# with Xylitol Unwrapped Spearmint 50 Sticks Suga...          1.0
# Stew Meat                                                   1.0
# Steamers Cauliflower & Cheese Sauce                         1.0
# Boneless Pork Chops                                         1.0
# Organic Breaded Chicken Breast Nuggets                      1.0
# Organic Blueberry Pomegranate Whole Milk Yogurt             1.0
# Organic Blood Orange & Honey Hard Candy                     1.0
# Bone Broth Protein Turmeric                                 1.0
# Organic Black Cherry Lowfat Yogurt                          1.0
# Spinach Hummus                                              1.0
# Stir Fry Mix                                                1.0
# Body Scrub Coconut Butter                                   1.0
# Organic Beets Veggie Chips                                  1.0
# ...

# %%
similar_to_Banana = similar_to_Banana.join(ratings['reordered_count'])
similar_to_Banana
# Out:
#                                                     Correlation  \
# product_name
# with Xylitol Unwrapped Spearmint 50 Sticks Suga...          1.0
# Stew Meat                                                   1.0
# Steamers Cauliflower & Cheese Sauce                         1.0
# Boneless Pork Chops                                         1.0
# Organic Breaded Chicken Breast Nuggets                      1.0
# Organic Blueberry Pomegranate Whole Milk Yogurt             1.0
# Organic Blood Orange & Honey Hard Candy                     1.0
# Bone Broth Protein Turmeric                                 1.0
# Organic Black Cherry Lowfat Yogurt                          1.0
# Spinach Hummus                                              1.0
# Stir Fry Mix                                                1.0
# Body Scrub Coconut Butter                                   1.0
# Organic Beets Veggie Chips                                  1.0
# ...

# %%
similar_to_Banana[similar_to_Banana['reordered_count'] >=5].sort_values('Correlation',ascending=False)
similar_to_Banana.head()
# Out:
#                                                     Correlation  \
# product_name
# with Xylitol Unwrapped Spearmint 50 Sticks Suga...          1.0
# Stew Meat                                                   1.0
# Steamers Cauliflower & Cheese Sauce                         1.0
# Boneless Pork Chops                                         1.0
# Organic Breaded Chicken Breast Nuggets                      1.0
#
#                                                     reordered_count
# product_name
# with Xylitol Unwrapped Spearmint 50 Sticks Suga...                4
# Stew Meat                                                         9
# Steamers Cauliflower & Cheese Sauce                              12
# Boneless Pork Chops                                               3
# Organic Breaded Chicken Breast Nuggets                            4
